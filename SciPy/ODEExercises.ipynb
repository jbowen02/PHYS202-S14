# %% [markdown]
# # ODE Exercises

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot.

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def deriv(theta_current,t):  # return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])

# %%
g = 9.8
ell = 0.5
th0 = [0., pi/4, pi/2, 3*pi/4, pi]

t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
theta_init_1 = np.array([th0[0], omega0])
theta_1 = odeint(deriv,theta_init_1,t)

theta_init_2 = np.array([th0[1], omega0])
theta_2 = odeint(deriv,theta_init_2,t)

theta_init_3 = np.array([th0[2], omega0])
theta_3 = odeint(deriv,theta_init_3,t)

theta_init_4 = np.array([th0[3], omega0])
theta_4 = odeint(deriv,theta_init_4,t)

theta_init_5 = np.array([th0[4], omega0])
theta_5 = odeint(deriv,theta_init_5,t)

plt.plot(t,theta_1[:,0],'r',label="Initial Angle = 0")
plt.plot(t,theta_2[:,0],'b',label="Initial Angle = $\pi$/4")
plt.plot(t,theta_3[:,0],'g',label="Initial Angle = $\pi$/2")
plt.plot(t,theta_4[:,0],'black',label="Initial Angle = $\pi$/4")
plt.plot(t,theta_5[:,0],'purple',label="Initial Angle = $\pi$")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
#plt.ylim(-1.,1.5)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %% [markdown]
# #### What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4?

# %% [markdown]
# The period increases as the initial angle increases.

# %% [markdown]
# #### What happens to the trajectory when the initial angle is 0 and π ?

# %% [markdown]
# When the initial angle is zero, the pendulum does not do anything because it has no angular velocity in the x axis.
#
# When the initial angle is π, the pendulum ball is stright up, and as the time progresses, the ball just falls with no angular velocity in the x direction.

# %% [markdown]
# #### (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
g = 9.8
ell = 0.5
th0 = .95*pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.

theta_init_6 = np.array([th0, omega0])
theta_6 = odeint(deriv,theta_init_6,t)
plt.plot(t,theta_6[:,0],'purple',label="theta vs t")
plt.plot(t,theta_6[:,1],'green',label="omega vs t")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad), \omega (rad/s)$',fontsize=20)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %%
theta_init_6 = np.array([th0, omega0])
theta_6 = odeint(deriv,theta_init_6,t)
plt.plot(theta_6[:,0],theta_6[:,1],'purple',label="omega vs theta")
plt.xlabel(r'$\theta$',fontsize=20)
plt.ylabel(r'$\omega$',fontsize=20)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %% [markdown]
# #### (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓ(1−cos(θ))+12ℓ2ω2 ).
#
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
E_over_m = g*ell*(1-np.cos(theta_6[:,0])) + (0.5)*ell**2*theta_6[:,1]**2
plt.plot(t,E_over_m,'purple')
plt.xlabel(r'$Time (s)$',fontsize=20)
plt.ylabel(r'$Energy/Mass (J/kg)$',fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# The energy is not exactly constant, but the scale of the y-axis means that this is within a small enough margin of error.

# %% [markdown]
# #### (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
th0 = [0., pi/4, pi/2, 3*pi/4, pi]
t = np.arange(0.,50.+0.01,0.01)
theta_init_5 = np.array([th0[4], omega0])
theta_5 = odeint(deriv,theta_init_5,t)
plt.plot(t,theta_5[:,0],'purple',label="theta vs t")
plt.plot(t,theta_5[:,1],'green',label="omega vs t")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad), \omega (rad/s)$',fontsize=20)
plt.xlim(0.,50.)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %%
plt.plot(theta_5[:,0],theta_5[:,1],'purple',label="omega vs theta")
plt.xlabel(r'$\theta$',fontsize=20)
plt.ylabel(r'$\omega$',fontsize=20)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %%
E_over_m = g*ell*(1-np.cos(theta_5[:,0])) + (0.5)*ell**2*theta_5[:,1]**2
t = np.arange(0.,50.+0.01,0.01)
plt.plot(t,E_over_m,'purple')
plt.xlabel(r'$Time (s)$',fontsize=20)
plt.ylabel(r'$Energy/Mass (J/kg)$',fontsize=20)
plt.xlim(0.,50.)
plt.grid()
plt.show()

# %%
th0 = [0., pi/4, pi/2, 3*pi/4, pi]
t = np.arange(0.,50.+0.01,0.01)
theta_init_5 = np.array([th0[4], omega0])
theta_5 = odeint(deriv,theta_init_5,t,atol=1e-10,rtol=1e-9)
plt.plot(t,theta_5[:,0],'purple',label="theta vs t")
plt.plot(t,theta_5[:,1],'green',label="omega vs t")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad), \omega (rad/s)$',fontsize=20)
plt.xlim(0.,50.)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()
